# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, accuracy_score
from sklearn.ensemble import IsolationForest
from sklearn.neighbors import LocalOutlierFactor

# %%
df= pd.read_csv('creditcard.csv')

# %%
display(df.info)
# Out:
# <bound method DataFrame.info of             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
print('Number of records')
len(df.Class)
# Out:
# Number of records
# 284807

# %%
fraud = df[(df['Class'] == 1)]
print('Fraud Record')
display(fraud)
pd.set_option('display.max_rows', None)
# Out:
# Fraud Record
#             Time         V1         V2         V3         V4         V5  \
# 541        406.0  -2.312227   1.951992  -1.609851   3.997906  -0.522188
# 623        472.0  -3.043541  -3.157307   1.088463   2.288644   1.359805
# 4920      4462.0  -2.303350   1.759247  -0.359745   2.330243  -0.821628
# 6108      6986.0  -4.397974   1.358367  -2.592844   2.679787  -1.128131
# 6329      7519.0   1.234235   3.019740  -4.304597   4.732795   3.624201
# 6331      7526.0   0.008430   4.137837  -6.240697   6.675732   0.768307
# 6334      7535.0   0.026779   4.132464  -6.560600   6.348557   1.329666
# 6336      7543.0   0.329594   3.712889  -5.775935   6.078266   1.667359
# 6338      7551.0   0.316459   3.809076  -5.615159   6.047445   1.554026
# 6427      7610.0   0.725646   2.300894  -5.329976   4.007683  -1.730411
# 6446      7672.0   0.702710   2.426433  -5.234513   4.416661  -2.170806
# 6472      7740.0   1.023874   2.001485  -4.769752   3.819195  -1.271754
# ...

# %%
print('Number of fraud credit card transcation : ',len(fraud))
# Out:
# Number of fraud credit card transcation :  492

# %%
NotFraud=df[(df['Class'] == 0)]
print('Number of Valid transcation : ',len(NotFraud))
# Out:
# Number of Valid transcation :  284315

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.758702e-12 -8.252296e-13 -9.637438e-13  8.316234e-13
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   1.592013e-13  4.247308e-13 -3.050183e-13  8.692882e-14 -1.179710e-12
# ...

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(),cmap="Blues")
# Out:
# <AxesSubplot:>

# %%
OutlierFraction = len(fraud)/float(len(NotFraud))
print('The outlier Fraction is: ',OutlierFraction)
# Out:
# The outlier Fraction is:  0.0017304750013189597

# %%
X = df.drop('Class',axis = 1) # X is input
y = df['Class']
