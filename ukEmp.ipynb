# %%
import pandas as pd

# %%
df=pd.read_excel('nomis_2023_04_05_110720.xlsx')

# %%
df.describe()
# Out:
#        total workforce jobs in number           %         Year
# count                    2.400000e+02  240.000000   240.000000
# mean                     1.771877e+06    5.002917  2021.000000
# std                      1.414389e+06    3.991617     0.818203
# min                      4.065600e+04    0.100000  2020.000000
# 25%                      5.647035e+05    1.575000  2020.000000
# 50%                      1.592253e+06    4.500000  2021.000000
# 75%                      2.740750e+06    7.700000  2022.000000
# max                      4.980040e+06   14.200000  2022.000000

# %%
display(df.info)
# Out:
# <bound method DataFrame.info of                                               Industry  \
# 0                A : Agriculture, forestry and fishing
# 1                             B : Mining and quarrying
# 2                                    C : Manufacturing
# 3    D : Electricity, gas, steam and air conditioni...
# 4    E : Water supply; sewerage, waste management a...
# 5                                     F : Construction
# 6    G : Wholesale and retail trade; repair of moto...
# 7                       H : Transportation and storage
# 8        I : Accommodation and food service activities
# 9                    J : Information and communication
# 10              K : Financial and insurance activities
# 11                          L : Real estate activities
# 12   M : Professional, scientific and technical act...
# 13   N : Administrative and support service activities
# 14   O : Public administration and defence; compuls...
# ...

# %%
display(df)
pd.set_option('display.max_rows', None)
# Out:
#                                               Industry  \
# 0                A : Agriculture, forestry and fishing
# 1                             B : Mining and quarrying
# 2                                    C : Manufacturing
# 3    D : Electricity, gas, steam and air conditioni...
# 4    E : Water supply; sewerage, waste management a...
# 5                                     F : Construction
# 6    G : Wholesale and retail trade; repair of moto...
# 7                       H : Transportation and storage
# 8        I : Accommodation and food service activities
# 9                    J : Information and communication
# 10              K : Financial and insurance activities
# 11                          L : Real estate activities
# 12   M : Professional, scientific and technical act...
# 13   N : Administrative and support service activities
# 14   O : Public administration and defence; compuls...
# 15                                       P : Education
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 5 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Industry                        240 non-null    object
#  1   total workforce jobs in number  240 non-null    int64
#  2   %                               240 non-null    float64
#  3   Quarter                         240 non-null    object
#  4   Year                            240 non-null    int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 9.5+ KB

# %%
df.plot(x='Quarter',y='%')
# Out:
# <AxesSubplot:xlabel='Quarter'>

# %%
df.groupby(df['Year'])['total workforce jobs in number'].sum()
# Out:
# Year
# 2020    139978063
# 2021    140725654
# 2022    144546780
# Name: total workforce jobs in number, dtype: int64

# %%
df.groupby(['Year','Quarter'])['total workforce jobs in number'].sum()
# Out:
# Year  Quarter
# 2020  Q1         35612871
#       Q2         35177961
#       Q3         34636410
#       Q4         34550821
# 2021  Q1         34759726
#       Q2         35149323
#       Q3         35374337
#       Q4         35442268
# 2022  Q1         35798909
#       Q2         36119397
#       Q3         36208868
#       Q4         36419606
# Name: total workforce jobs in number, dtype: int64

# %%
df.groupby(['Year','Quarter'])['total workforce jobs in number'].sum().unstack().plot(kind='bar', stacked=True, title='Total workforce Job Price per Year and  Quarter  ')
# Out:
# <AxesSubplot:title={'center':'Total workforce Job Price per Year and  Quarter  '}, xlabel='Year'>
